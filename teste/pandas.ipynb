# %%
import sqlite3

conn = sqlite3.connect("../ecommerce.db")
print("Conectado com sucesso")
# Out:
# Conectado com sucesso

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\joao.almeida\AppData\Local\Python\pythoncore-3.14-64\python.exe

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("../ecommerce.db")

df = pd.read_sql(
    "SELECT name FROM sqlite_master WHERE type='table' AND name LIKE '%gold%'",
    conn
)

df
# Out:
#                   name
# 0            gold_kpis
# 1  gold_orders_by_city
# 2    gold_top_products
